# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#2398d0;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">Introduction</h1>
#
# </div>

# %% [markdown]
# ![](https://revca-assets.s3.ap-south-1.amazonaws.com/Blue+Yellow+Futuristic+Virtual+Technology+Blog+Banner.png)

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:15px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#2398d0;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold">ANAI</h1>
#     <h3 style="text-align:center;font-weight: bold">ANAI is an Automated Machine Learning Python Library that works with tabular data. It is intended to save time when performing data analysis. It will assist you with everything right from the beginning i.e Ingesting data using the inbuilt connectors, preprocessing, feature engineering, model building, model evaluation, model tuning and much more.</h3>
#
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#2398d0;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
#         <h1 style="text-align:center;font-weight: bold">Let's Democratize AI</h1>
#
#
#
# </div>

# %%
# %pip install anai-opensource

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#2398d0;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">Importing Libraries</h1>
#
#
#
# </div>

# %%
import anai
from anai.preprocessing import Preprocessor

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#2398d0;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">Loading Data</h1>
#
#
#
# </div>

# %%
df = anai.load(
    df_filepath='healthcare-dataset-stroke-data.csv')
# Out:
# Loading Data [*]
#
# Data Loaded Successfully [ ✓ ]

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#2398d0;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">ANAI Preprocessing Pipeline</h1>
#
#
#
# </div>

# %%
prep = Preprocessor(dataset = df, target = 'stroke')

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#2398d0;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold;">Summaries</h2>
#
#
#
# </div>

# %%
summary = prep.summary()
summary.head(10)
# Out:
#                        Stats
# No. of Cells           61320
# No. of Variables          12
# No. of Records          5110
# Missing Cells          0.3 %
# Missing Cells Count      201
# Duplicacy             0.00 %
# Duplicate Cell Count       0
# Anomaly Count            256

# %%
column_summary = prep.column_summary()
column_summary.head(24)
# Out:
#                                                   id  \
# Type Error                  ID column is not allowed
# hide                                            True
# Type                                             NaN
# Missing Value %                                  NaN
# Mean                                             NaN
# Mode                                             NaN
# Maximum value                                    NaN
# Median                                           NaN
# Minimum value                                    NaN
# Standard Deviation                               NaN
# 99% Quartile                                     NaN
# 90% Quartile                                     NaN
# 66% Quartile                                     NaN
# 33% Quartile                                     NaN
# 10% Quartile                                     NaN
# 1% Quartile                                      NaN
# Variance                                         NaN
# ...

# %% [markdown]
# ### As we can see there are 0.3% missing cells. We will impute them now.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#2398d0;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold;">Imputing Missing Values</h2>
#
#
#
# </div>

# %%
df1 = prep.impute(method = 'mean')

# %%
df1.isna().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#2398d0;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h2 style="text-align:center;font-weight: bold;">Preparing Data</h2>
#
#
#
# </div>

# %%
features, labels = prep.encode(split = True)

# %%
features.head(4)
# Out:
#       id    gender   age  hypertension  heart_disease  ever_married  \
# 0   9046  0.048728  67.0             0              1      0.048728
# 1  51676  0.048728  61.0             0              0      0.524364
# 2  31112  0.524364  80.0             0              1      0.682909
# 3  60182  0.524364  49.0             0              0      0.762182
#
#    work_type  Residence_type  avg_glucose_level   bmi  smoking_status
# 0   0.048728        0.048728             228.69  36.6        0.048728
# 1   0.048728        0.048728             202.21   NaN        0.048728
# 2   0.524364        0.524364             105.92  32.5        0.524364
# 3   0.682909        0.524364             171.23  34.4        0.048728

# %% [markdown]
# ##

# %%
X_train, X_val, y_train, y_val, scaler = prep.prepare(features, labels, test_size = 0.2, random_state = 42, smote = False, k_neighbors = 3)

# %%
X_train.shape, X_val.shape, y_val.shape, y_train.shape
# Out:
# ((4088, 11), (1022, 11), (1022,), (4088,))

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#2398d0;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">ANAI's AutoML Pipeline</h1>
#
#
#
# </div>

# %%
ai = anai.run(filepath='/Users/arshanwar/Projects/AutoML/open_source/ANAI/examples/healthcare-dataset-stroke-data.csv',
              target='stroke', predictor=['rfc', 'cat', 'xgb', 'lgbm', 'ext'])
# Out:
# ...
# Task: Classification
#
#
# ░█████╗░███╗░░██╗░█████╗░██╗
# ██╔══██╗████╗░██║██╔══██╗██║
# ███████║██╔██╗██║███████║██║
# ██╔══██║██║╚████║██╔══██║██║
# ██║░░██║██║░╚███║██║░░██║██║
# ╚═╝░░╚═╝╚═╝░░╚══╝╚═╝░░╚═╝╚═╝
#
#
# Started ANAI [ ✓ ]
#
# Preprocessing Started [*]
#
# Imputing Missing Values by mean [*]
#
# Imputing Done [ ✓ ]
#
# Preprocessing Done [ ✓ ]
#
# Training ANAI [*]
#
# Ensembling on top 5 models
#
# Training Done [ ✓ ]
#
# Results Below
#                        Name   Accuracy  Cross Validated Accuracy
# 0  Random Forest Classifier  99.412916                 99.363824
# 1        Stacking Ensembler  99.510000                 99.340000
# 2    Extra Trees Classifier  99.412916                 99.314864
# 3      Max Voting Ensembler  99.410000                 99.310000
# 4       CatBoost Classifier  99.412916                 99.265904
# 5        XGBoost Classifier  99.412916                 99.241574
# 6       LightGBM Classifier  99.412916                 99.143715
# ...

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#2398d0;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">Explainable ANAI</h1>
#
#
#
# </div>

# %%
ai.explain('perm')
# Out:
# Explaining Best ANAI model [*]
# Explaining ANAI Done [ ✓ ]

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#2398d0;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">Leaderboard</h1>
#
#
#
# </div>

# %%
ai.result()
# Out:
#                        Name   Accuracy  Cross Validated Accuracy  \
# 0  Random Forest Classifier  99.412916                 99.363824
# 1        Stacking Ensembler  99.510000                 99.340000
# 2    Extra Trees Classifier  99.412916                 99.314864
# 3      Max Voting Ensembler  99.410000                 99.310000
# 4       CatBoost Classifier  99.412916                 99.265904
# 5        XGBoost Classifier  99.412916                 99.241574
# 6       LightGBM Classifier  99.412916                 99.143715
#
#                                                Model
# 0  (DecisionTreeClassifier(max_features='auto', r...
# 1  StackingClassifier(cv=10,\n                   ...
# 2  (ExtraTreeClassifier(random_state=840703915), ...
# 3  VotingClassifier(estimators=[('Random Forest C...
# 4  <catboost.core.CatBoostClassifier object at 0x...
# 5  XGBClassifier(base_score=0.5, booster='gbtree'...
# 6                                   LGBMClassifier()

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:#2398d0;
#            color:Black;
#            font-family:cursive;
#             padding:5px 5px 5px 5px;
#            ">
# <h1 style="text-align:center;font-weight: bold;">Final Notes</h1>
#     <h3 style="text-align:center;font-weight: bold">The purpose of this Notebook was to give overview of ANAI and show how easy it is to use a ANAI. </h3>
#
#
#
# </div>
